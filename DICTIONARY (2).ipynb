# %% [markdown]
# # **DICTIONARY**

# %% [markdown]
# dictionary is a collection is ordered, changable do not allow to duplicate,
# mutable, infainate set,iterable, key values pair, value index by key,

# %%
x={"name":"sabitha","age":23,"place":"manjeri"}
print(x)
# Out:
# {'name': 'sabitha', 'age': 23, 'place': 'manjeri'}

# %%
print(type(x))
# Out:
# <class 'dict'>

# %%
x["age"]=45
print(x)
# Out:
# {'name': 'sabitha', 'age': 45, 'place': 'manjeri'}

# %% [markdown]
# we can pass the list as the value not key,
# all data types float, complex ,int, string we can pass as key

# %%
x={(3,4): "sabitha","phoneno":3245545335,"job":"teacher"}
print(x)
# Out:
# {(3, 4): 'sabitha', 'phoneno': 3245545335, 'job': 'teacher'}

# %% [markdown]
# all immutable data types can be pass as the key such as tuple

# %%
a={'name':'sabitha','age': 43,'place':'manjeri'}
a['name']='misna'
print(a)
a.update({'job':"teacher"})
print(a)
# Out:
# {'name': 'misna', 'age': 43, 'place': 'manjeri'}
# {'name': 'misna', 'age': 43, 'place': 'manjeri', 'job': 'teacher'}

# %% [markdown]
# # **DELETE**

# %%
a={'name':"sabitha",'age':43,"place":'manjeri'}
a.popitem()
print(a)
# Out:
# {'name': 'sabitha', 'age': 43}

# %%
x={'name':'sabitha','age':'21','place':'manjeri','job':'teacher'}
del x['name']
print(x)
# Out:
# {'age': '21', 'place': 'manjeri', 'job': 'teacher'}

# %%
x.pop('age')
print(x)
# Out:
# {'place': 'manjeri', 'job': 'teacher'}

# %%
print(x['place'])
print(x)
# Out:
# manjeri
# {'place': 'manjeri', 'job': 'teacher'}

# %%
print(x.keys())
# Out:
# dict_keys(['place', 'job'])

# %%
print(x.values())
# Out:
# dict_values(['manjeri', 'teacher'])

# %%
print(x['job'])
# Out:
# teacher

# %%
print(x.get('job'))
# Out:
# teacher

# %% [markdown]
# **string** **operation**

# %%
x='python is is a simple language'
print(len(x))
# Out:
# 30

# %%
print(x.count('is'))
# Out:
# 2

# %%
print(x.count('a'))
# Out:
# 3

# %% [markdown]
# ```
# **# This is formatted as code**
# ```
#
# **string** **indexing**

# %%
print(x[7])
# Out:
# i

# %%
print(x[-1])
# Out:
# e

# %%
print(x[6])

# %% [markdown]
# **concentrative** **method**

# %%
x= "python is simple languege"
y="also powerful"
z=(x+y)
print(z)
# Out:
# python is simple languegealso powerful

# %%
a= "python is simple languege"+ "also powerful"
print(a)
# Out:
# python is simple languegealso powerful

# %%
x= "python is a simple languege"
y=  "also powerful"
z=x.replace("simple","both simple and powerful")
print(z)
# Out:
# python is a both simple and powerful languege

# %%
x= "python is simple languege"
x.startswith("p")
# Out:
# True

# %%
x.endswith("e")
# Out:
# True

# %%
x.startswith('is',7,9)
# Out:
# True

# %%
x.endswith('is')
# Out:
# False

# %%
x.endswith('is',2,9)
# Out:
# True

# %%
x.startswith('is')
# Out:
# False

# %%
txt='hello, welcome to my world.'
x=txt.endswith(".")
print(x)
# Out:
# True
