# %% [markdown]
# what is module in python?

# %% [markdown]
# The module is simple python file that contains collections of the function and global variables and with having a py extension file. it is an executable file and to organize all the the module we have the concept called package in python.
# examples of the modules:
# datatind, regex random, calender.

# %% [markdown]
# what is package in python?

# %% [markdown]
# the package is simple directory having collections of modules . This directory contains in python modules.The package is simple a namespace. The package also contains sub-package inside it.
# example of the package:
# numpy,pandas.

# %% [markdown]
# what is library in python?

# %% [markdown]
# The library is having a collection of related functionally of the codes that allows youto perform many task without writing your code.
# Ts is reuseble chunk of code that we can use by imporing it into our programme, we can just use it by importing that library and calling the method of that library with a periodi.
# Examples of the libraries:
# matplolib,pytorch,pygame,seaborn.
