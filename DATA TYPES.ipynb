# %% [markdown]
# # **DATA TYPES**

# %% [markdown]
#  text types str
#
# we can use string with single double and trible quotes.
#    int,
#    complex,
#    float

# %%
name="sabitha"
print(name)
# Out:
# sabitha

# %%
type(name)
# Out:
# str

# %%
name=3
print(name)
# Out:
# 3

# %%
print(type(name))
# Out:
# <class 'int'>

# %%
name=3.5
print(name)
# Out:
# 3.5

# %%
print(type(name))
# Out:
# <class 'float'>

# %%
name='''3'''
print(name)
# Out:
# 3

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
name='''safrnldnrlnlnc
        gfegkcvfm'''
print(name)
# Out:
# safrnldnrlnlnc
#         gfegkcvfm

# %%
name=20+8j
print(type(name))
# Out:
# <class 'complex'>

# %%
print(name.real)
# Out:
# 20.0

# %%
print(name.imag)
# Out:
# 8.0

# %% [markdown]
# # BOOLEAN DATA  TYPES
# TRUE,
# FALSE

# %%
X=True
print(type(X))
# Out:
# <class 'bool'>

# %%
print(True+True)
# Out:
# 2

# %%
print(False+True)
# Out:
# 1

# %% [markdown]
# NONE TYPE

# %%
a=None
print(a)
# Out:
# None

# %%
print(type(a))
# Out:
# <class 'NoneType'>

# %% [markdown]
# # DATA TYPES CASTING

# %%
age=54
print(type(age))
# Out:
# <class 'int'>

# %%
age=float(age)
print(type(age))
# Out:
# <class 'float'>

# %%
print(age)
# Out:
# 54.0

# %% [markdown]
# # LIST

# %% [markdown]
# list is a order sequence, mutable collection of data
# infainate length, iterable.
# allow to dublicate members and return with squre brackets

# %%
list=["sabitha","shifa", "suhana",2,4.3]
print(list)
# Out:
# ['sabitha', 'shifa', 'suhana', 2, 4.3]

# %% [markdown]
# # TUPLE

# %% [markdown]
# Its an ordered sequence, immutable, infanite length, iterable,allow to duplicatemembers and retrun with() brackects.

# %%
tuple=("sabitha","misna",2,3.4)
print(tuple)
# Out:
# ('sabitha', 'misna', 2, 3.4)

# %%
print(type(tuple))
# Out:
# <class 'tuple'>

# %%
tuple=(4,3,3.4,7)
print(sum(tuple))
print(min(tuple))
print(max(tuple))
# Out:
# 17.4
# 3
# 7

# %%
name=(1,3,6,8,4.5,7.8)
print(name.count(3))
print(name.index(6))
# Out:
# 1
# 2
