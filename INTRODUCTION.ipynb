# %% [markdown]
# # ***PYTHON***

# %% [markdown]
# python is a popular language.it was created by guidio

# %% [markdown]
# python is populaur programming language.
# python can used to databaise systems, it can read and modify files.python can be used to handle big data and perform complex mathematical operations python is platforms independ

# %%
print('sabitha')
# Out:
# sabitha

# %% [markdown]
# # PYTHON VARIABLE
# variables are assigned to store values.variable are created when you assigne a value to

# %%
a=8
print(a)
# Out:
# 8

# %% [markdown]
# **CASE** **SENSITIVE**

# %%
a=5
A="dog"

# %% [markdown]
# "a" and "A" are considered different in python

# %% [markdown]
# **INDENTATION**

# %% [markdown]
# *indentation refers to space at the beginning of code line.*
# where in other programming langueges the indentations is code readabilty onlyindetation .python is very important
# python uses to indetations indicate block of code.
# *italicized text*

# %%
if 3>1:
   print(" three is greater than one")
# Out:
#  three is greater than one

# %%
if 3>1:
print('three is greater than one')
# Out:
#   File "<ipython-input-4-dc7e84237511>", line 2
#     print('three is greater than one')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# # COMMENTS

# %% [markdown]
# python has comment for the declaring a variable.
#
# comments pythons has commenting capablity for the purpose of code
# comment started with a #.
# python does
#             really have synthax for multil line  comments
# to add multi line comments you could use # for each lines

# %%
#print("hello world")
print("sabitha,""misna")
# Out:
# sabitha,misna

# %% [markdown]
# **MULTILINE** **COMMENTS**

# %%
#print("sabitha")
#vrbkdckck
#bm lmvfl vyvc
print(3)
# Out:
# 3

# %%
'''
sabitha
shifa
suhana
'''
print(3.5)
# Out:
# 3.5

# %% [markdown]
# **GET** **THE** **TYPE**

# %%
a=78
print(type(a))
# Out:
# <class 'int'>

# %%
a="r"
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# # AUTOMATIC MEMORY ALLOCATION

# %% [markdown]
# python follows automatic memmory alocation
# a=7
# a=8
# print(x)
# 8

# %%
a=7
a=8
print(a)
# Out:
# 8

# %% [markdown]
# # CASTING

# %% [markdown]
# if you wants to specify the data type of a variable , this can be done by casting.

# %%
x=str(3)
y=float(3)
z=int(3)
print(x)
# Out:
# 3

# %%
print(y)
# Out:
# 3.0

# %%
print(z)
# Out:
# 3

# %% [markdown]
# a variable name must started with a letter or underscore character.and must not witha number. a variable name can only contains alpha numeric characters and underscore.it is a case sensitive.

# %% [markdown]
#  **ILLEGAL** **VARIABLE** **NAMES**

# %% [markdown]
# 2NAME="SABITHA"

# %% [markdown]
# a-ge=34
