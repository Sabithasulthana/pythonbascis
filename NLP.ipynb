# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwordss=stopwords.words('english')
stopwordss
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
len(stopwordss)
# Out:
# 179

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
senstence= 'This is  my home'
tokens=nltk.word_tokenize(senstence)
tokens
# Out:
# ['This', 'is', 'my', 'home']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
sentence= 'at Eight o Clock on Monday , Hello How Are You'
stopwordss=set(stopwords.words('english'))
tokens=word_tokenize(sentence)
tokens
words=[ W for W in tokens if not W in stopwordss]
words
# Out:
# ['Eight', 'Clock', 'Monday', ',', 'Hello', 'How', 'Are', 'You']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
sentence= 'at Eight o Clock on Monday , Hello How Are You'
stopwordss=set(stopwords.words('english'))
tokens=word_tokenize(sentence)
tokens
words=[ W. lower() for W in tokens if not W in stopwordss]
words
# Out:
# ['eight', 'clock', 'monday', ',', 'hello', 'how', 'are', 'you']

# %%
#this is good
#this not good
# ngrms
#ngram=1 ngram=2 ngram=3
#this    this is  this is not


#is       not good

#good

# %%
from nltk.util import ngrams
sentence= 'at Eight o Clock on Monday , Hello How Are You'
Ngrams=ngrams(nltk.word_tokenize(sentence),n=3)
for grams in Ngrams:
  print(grams)
# Out:
# ('at', 'Eight', 'o')
# ('Eight', 'o', 'Clock')
# ('o', 'Clock', 'on')
# ('Clock', 'on', 'Monday')
# ('on', 'Monday', ',')
# ('Monday', ',', 'Hello')
# (',', 'Hello', 'How')
# ('Hello', 'How', 'Are')
# ('How', 'Are', 'You')

# %%
from nltk.stem import SnowballStemmer
sb=SnowballStemmer('english')
words=['eight', 'clock','programs','programming','programmer','program','monday','morning',',','hello']
for w in words:
  print(w, " , ",sb.stem(w))
# Out:
# eight  ,  eight
# clock  ,  clock
# programs  ,  program
# programming  ,  program
# programmer  ,  programm
# program  ,  program
# monday  ,  monday
# morning  ,  morn
# ,  ,  ,
# hello  ,  hello

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
words=['eight', 'clock','programs','programming','monday','morning',',','hello']
print('Words, Porter Stem')
for w in words:
  print(w, " , ",ps.stem(w))
# Out:
# Words, Porter Stem
# eight  ,  eight
# clock  ,  clock
# programs  ,  program
# programming  ,  program
# monday  ,  monday
# morning  ,  morn
# ,  ,  ,
# hello  ,  hello

# %% [markdown]
# **Lemmatization**

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()
print('rocks',lem.lemmatize('rocks'))
print('corpora',lem.lemmatize('corpora'))
print('better',lem.lemmatize('better'))
print('cats',lem.lemmatize('cats'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# rocks rock
# corpora corpus
# better better
# cats cat

# %% [markdown]
# **part** **of** **speech** **tagging**:
# in nlp part of speech tagging is the process of assinging grammatical categories(like noun, verb, adjective,etc)

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()
print('rocks as noun:',lem.lemmatize('rocks'))
print('thought as noun:',lem.lemmatize('thought'))
print('corpora as noun:',lem.lemmatize('corpora',pos='n'))
print('runing as verb:',lem.lemmatize('runing',pos='v'))
print('played as verb:',lem.lemmatize('played',pos='v'))
# Out:
# rocks as noun: rock
# thought as noun: thought
# corpora as noun: corpus
# runing as verb: run
# played as verb: play

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()

print('rocks as noun:',lem.lemmatize('rocks',pos='n'))
print('thought as verb:',lem.lemmatize('thought',pos='v'))
print('play as adverb:',lem.lemmatize('play',pos='r'))
print('better as adjective:',lem.lemmatize('better',pos='a'))
# Out:
# rocks as noun: rock
# thought as verb: think
# play as adverb: play
# better as adjective: good

# %% [markdown]
# **example**

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwordss=stopwords.words('english')
stopwordss
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
senstence= 'hello my dear friends,how are you '
tokens=nltk.word_tokenize(senstence)
tokens
# Out:
# ['hello', 'my', 'dear', 'friends', ',', 'how', 'are', 'you']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
sentence= 'i am looking for you, what are you doing in seven o clock'
stopwordss=set(stopwords.words('english'))
tokens=word_tokenize(sentence)
tokens
words=[ W for W in tokens if not W in stopwordss]
words
# Out:
# ['looking', ',', 'seven', 'clock']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
sentence= 'i am Looking for you , what are you doing in Seven o Clock'
stopwordss=set(stopwords.words('english'))
tokens=word_tokenize(sentence)
tokens
words=[ W. lower() for W in tokens if not W in stopwordss]
words
# Out:
# ['looking', ',', 'seven', 'clock']

# %%
from nltk.util import ngrams
sentence= ' i see a cat near my house, a beautiful cat'
Ngrams=ngrams(nltk.word_tokenize(sentence),n=5)
for grams in Ngrams:
  print(grams)
# Out:
# ('i', 'see', 'a', 'cat', 'near')
# ('see', 'a', 'cat', 'near', 'my')
# ('a', 'cat', 'near', 'my', 'house')
# ('cat', 'near', 'my', 'house', ',')
# ('near', 'my', 'house', ',', 'a')
# ('my', 'house', ',', 'a', 'beautiful')
# ('house', ',', 'a', 'beautiful', 'cat')

# %%
from nltk.stem import SnowballStemmer
sb=SnowballStemmer('english')
words=['nine','jumbing','jum','playing','play','plays','player','hello','seat',',','malayalam']
for w in words:
  print(w, " , ",sb.stem(w))
# Out:
# nine  ,  nine
# jumbing  ,  jumb
# jum  ,  jum
# playing  ,  play
# play  ,  play
# plays  ,  play
# player  ,  player
# hello  ,  hello
# seat  ,  seat
# ,  ,  ,
# malayalam  ,  malayalam

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
words=['nine','jumbing','jum','playing','play','plays','player','hello','seat',',','malayalam']
print('Words, Porter Stem')
for w in words:
  print(w, " , ",ps.stem(w))
# Out:
# Words, Porter Stem
# nine  ,  nine
# jumbing  ,  jumb
# jum  ,  jum
# playing  ,  play
# play  ,  play
# plays  ,  play
# player  ,  player
# hello  ,  hello
# seat  ,  seat
# ,  ,  ,
# malayalam  ,  malayalam

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()
words=['nine','jumbing','jum','playing','play','plays','player','hello','seat',',','malayalam']
for w in words:
  print(w, " , ",lem.lemmatize(w))
# Out:
# nine  ,  nine
# jumbing  ,  jumbing
# jum  ,  jum
# playing  ,  playing
# play  ,  play
# plays  ,  play
# player  ,  player
# hello  ,  hello
# seat  ,  seat
# ,  ,  ,
# malayalam  ,  malayalam
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()
print('sitting as noun:',lem.lemmatize('sitting'))
print('goes as noun:',lem.lemmatize('goes'))
print('juming as noun:',lem.lemmatize('jumbing',pos='n'))
print('attention as verb:',lem.lemmatize('attention',pos='v'))
print('learn as verb:',lem.lemmatize('learn',pos='v'))
# Out:
# sitting as noun: sitting
# goes as noun: go
# juming as noun: jumbing
# attention as verb: attention
# learn as verb: learn

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()

print('sitting as noun:',lem.lemmatize('sitting',pos='n'))
print('goes as verb:',lem.lemmatize('goes',pos='v'))
print('jumbing as adverb:',lem.lemmatize('jumbing',pos='r'))
print('learn as adjective:',lem.lemmatize('be',pos='a'))
