# %% [markdown]
# **EXCEPTION** **HANDLING**

# %%
num1=int(input('num1'))
num2=int(input('num2'))
z= num1/num2
print(z)
# Out:
# num110
# num25
# 2.0

# %%
num1 =int(input('num1'))
num2 =int(input('num2'))
try:
  num3=num1/num2
  print(num3)
except:
    print('an error exist')
# Out:
# num110
# num20
# an error exist

# %%
num1 =int (input("num1"))
num2= int(input('num2'))


try:
  num3=num1/num2
  print(num3)

except ZeroDivisionError as z:
    print(z)
# Out:
# num110
# num20
# division by zero

# %%
num1=int(input('num1'))
num2= int(input('num2'))

try:
  num3=num1/num2
  print(num3)
except Exception as v:
    print(v)
# Out:
# num110
# num20
# division by zero

# %%
    num1=int(input('num1'))
    num2=int(input('num2'))
    try:
      num3=num1/num2
      print(num3)
    except ValueError as e:
       print(e)
# Out:
# num110
# num2w
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-37d33dc9f18e> in <cell line: 2>()
#       1 num1=int(input('num1'))
# ----> 2 num2=int(input('num2'))
#       3 try:
#       4   num3=num1/num2
#       5   print(num3)
#
# ValueError: invalid literal for int() with base 10: 'w'

# %%
from logging import exception
num1=int(input('num1'))
num2=int(input('num2'))

try:

  num3=num1/num2
  print(num3)
except ValueError as e:
    print(e)
except Exception as v:
      print(v)
# Out:
# num110
# num20
# division by zero

# %%
try:
  num1=int(input('num1'))
  num2=int(input('num2'))
  num3=num1/num2
  print(num3)
except ValueError as e:
    print(e)
# Out:
# num110
# num2d
# invalid literal for int() with base 10: 'd'

# %%
try:
  num1=int(input('num1'))
  num2=int(input('num2'))
  num3=num1/num2
  print(num3)
except Exception as e:
    print(e)
else:
            print('there is no error')
finally:
              print('completed')
# Out:
# num110
# num25
# 2.0
# there is no error
# completed
