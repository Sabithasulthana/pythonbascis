# %% [markdown]
# # **CONDITIONS**

# %% [markdown]
#  Used to decide the path of  exectution

# %%
# if
#else
#elif

# %%
age=int(input('enter youer age :'))
if age>50:
      print("you are eligible for vaccination")
else:
     print('you are not eligible for vaccinaton')
# Out:
# enter youer age :20
# you are not eligible for vaccinaton

# %%
num=int(input('enter youer number'))


if num>0:
    print('positive')
elif num<0:
     print("negative")
else:
    print("zero")
# Out:
# enter youer number4
# positive

# %%
num= int(input('enter the number'))

if num>0:
      print(num,"positive")
elif num==0:
      print(num,'zero')
else:
     print(num,'negative')
# Out:
# enter the number3
# 3 positive

# %%
age= int(input('enter your age: '))

if age>10:
  print('lp')
elif age>13:
   print('hp')
elif age<14:
   print(" high school")
else:
   print('invalid')
# Out:
# enter your age: 10
#  high school

# %%
age=int(input('enter your age: '))
health=(input(     "health condition 1 for criticai,2 for nomal" ))
if age>60 and health==1:
  print(" not eligible for second dose")
elif age>60 and health ==2:
   print('eligible for second dose')
elif age<60 and health==1:
   print('elible for  first dose')
elif age>18 and health==1:
   print("eligble for for first dose")
else:
   print("not eligble" )
# Out:
# enter your age: 43
# health condition 1 for criticai,2 for nomal2
# not eligble
