# %% [markdown]
# **FILEHANDLING**

# %% [markdown]
# create file

# %% [markdown]
# Open file

# %% [markdown]
# Write file

# %% [markdown]
# Read file

# %% [markdown]
# Closing file

# %% [markdown]
# File handling is an important of any web application.pyrhon has several functions for creating,reading,updating,and deleting files.

# %% [markdown]
# The key function for working with files in python is the open()function.The open()functiontakes two parameters.filename,and mode.There are four differentmethords(modes) for opening a file.

# %%
open('filename','mode')

# %% [markdown]
# Mode Description

# %% [markdown]
# 'r'  = Read-defectvalue.opens file for resding. error if filedoesnot exist.

# %% [markdown]
# 'w'= This mode open file for  . if file does not exisit ,it creates anew file, if file exisit it truncates the file.

# %% [markdown]
# 'x'= Creates a new file, if filealready exisits,the operationfalis

# %% [markdown]
# 'a'= Open file in append mode .if file doesnot exist. it creates a new file

# %% [markdown]
#  't'=This the default mode it opens in text mode

# %% [markdown]
# 'b'= Thos the open in binary mode

# %% [markdown]
# '+'= This will open a file for reading and writing (updating)

# %% [markdown]
# How to create a text file

# %% [markdown]
# Create a the file with open

# %% [markdown]
# f= open(filename,writemode)

# %% [markdown]
# examples f= open('demo.txt','x')

# %% [markdown]
# 'w'= Letter in our arguments,which indicates write and will create afile.

# %% [markdown]
# if does not exist in libray

# %% [markdown]
# Plus sign indicates both read and write

# %%
f= open('demo34.txt','x')

# %%
f= open('/content/demo34.txt','w+')
