# %% [markdown]
# **K** **NEAREST** **NEIGHBOUR** **ALGORITHM**
#
# K nearest neighbour is one of the simplest machine learning algorithms based on supervised learning technique
#
# K NN algorithm assumes the similary b/w the nwe case/ data and available cases and put the new case into the category that is most similar to the available categories
#
# Knn algorithm stores all the available data and classifies new data points based on the similarity. this means when new data appears then it can be easily classsified into a well suite category by using k-nn algorithm.
#
# **K** **ALGORITHM**
#
# 1: Select the number k of the neighbours.
#
# 2: Calculate the euclidean distsnce of the k number of the neighbours.
#
# 3; Take the k nn as per the calculated eucledian distance.
#
# 4: Among these k neighbours, count the number of the data points in each category
#
# 5; Assign the new data points tothat catagory for which the number of the neighbour is maximum
#
# 6: Our model is ready
#
# **EUCLIDEAN** **DISTASNCE** **FORMULA**

# %% [markdown]
# $$d=\sqrt{x_2-x_1)^2+(y_2-y_1)^2}$$

# %% [markdown]
# Manhatten Formula

# %% [markdown]
# $$d = |x_2 - x_1| + |y_2 - y_1|$$

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
x= np.array([[150,50],[155,55],[160,60],[161,59],[158,65]])
y=np.array(['Medium','Medium','Large','Large','Large'])
test_point=np.array([[157,54]])
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x,y)
prediction=knn.predict(test_point)
print(f'The predicted targect for Height=157 and Weight =54 is:{prediction[0]}')
# Out:
# The predicted targect for Height=157 and Weight =54 is:Large

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.datasets import load_breast_cancer
# read data
cancer=load_breast_cancer()
cancer.target_names
df=pd.DataFrame(cancer.data,columns=cancer.feature_names)
df['target']=pd.Series(cancer['target'])
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.isna().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
sns.pairplot(df['mean radius',	'mean texture'	'mean perimeter',	'mean area',	'mean smoothness	'])
plt.show()

# %%
sns.pairplot(df[['mean compactness'	,'mean concavity','mean concave points','mean symmetry','mean fractal dimension']])
plt.show()

# %%
sns.pairplot(df[['concavity error','worst radius','worst concavity','mean perimeter','worst texture']])
plt.show()

# %%
df['target'].unique()
# Out:
# array([0, 1])

# %%
df['target'].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (569, 31)

# %%
print(f'number of rows:{df.shape[0]}')
print(f'number of columns:{df.shape[1]}')
# Out:
# number of rows:569
# number of columns:31

# %%
sns.histplot(df['target'])
plt.title('Target Distribution')
plt.xlabel('Target')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_matrix =df.corr()
correlation_matrix

# %%
plt.figure(figsize=(18,18))
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
Scaler=MinMaxScaler()
df=pd.DataFrame(Scaler.fit_transform(df),columns=df.columns)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     0.521037      0.022658        0.545989   0.363733         0.593753
# 1     0.643144      0.272574        0.615783   0.501591         0.289880
# 2     0.601496      0.390260        0.595743   0.449417         0.514309
# 3     0.210090      0.360839        0.233501   0.102906         0.811321
# 4     0.629893      0.156578        0.630986   0.489290         0.430351
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          0.792037        0.703140             0.731113       0.686364
# 1          0.181768        0.203608             0.348757       0.379798
# 2          0.431017        0.462512             0.635686       0.509596
# 3          0.811361        0.565604             0.522863       0.776263
# 4          0.347893        0.463918             0.518390       0.378283
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
from sklearn.model_selection import train_test_split
x= df.drop(['target'],axis=1)
y=df['target']
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42)
print('shape of the train data',x_train.shape)
print('shape of test data',x_test.shape)
print('shape of y_train',y_train.shape)
print('shape of y_test',y_test.shape)
# Out:
# shape of the train data (426, 30)
# shape of test data (143, 30)
# shape of y_train (426,)
# shape of y_test (143,)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
#n_neighbors=5
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print(f'Train score: {knn.score(x_train,y_train)}')
print(f'Test score:{knn.score(x_test,y_test)}')
# Out:
# Train score: 0.9812206572769953
# Test score:0.965034965034965

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.965034965034965
