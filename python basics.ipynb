# %%
#1
print('hello,how are you')
# Out:
# hello,how are you

# %%
#2
x=input('enter youer name')
print('hello'+x+'how are you')
# Out:
# enter youer namesabitha
# hellosabithahow are you

# %%
#3
x=int(input('enter youer number'))
y=int(input('enter youer number'))
print(x+y)
print(sum)
# Out:
# enter youer number20
# enter youer number30
# 50
# <built-in function sum>

# %%
#4
x=input('enter a string')
print(x)
print(len(x))
# Out:
# enter a stringhello how are you
# hello how are you
# 18

# %%
#5
x= input('enter a sring')
print(x.split())
print(len(x.split()))
# Out:
# enter a sringhello world
# ['hello', 'world']
# 2

# %%
#7
x=input("enter a string")
y=x.upper()
print(y)
# Out:
# enter a stringsabitha
# SABITHA

# %%
#9
x= input('enter your string')
if x== x[::-1]:
 print('the strings is palidrome')
else:
 print('the string is not palidrome')
# Out:
# enter your stringmalayalam
# the strings is palidrome

# %%
#10
x=input('enter a string')
y=input('enter a substring')
if y in x:
  print('substring found')
else:
  print('substring not found')
# Out:
# enter a stringhello sabitha
# enter a substringsabitha
# substring found
