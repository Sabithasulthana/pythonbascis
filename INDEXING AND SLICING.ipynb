# %% [markdown]
# # **INDEXING**

# %% [markdown]
# **positive** **and** **negative** **indexing**

# %%
x=[['name',34],'sabitha',"misbna","arifa"]
print(x[2])
# Out:
# misbna

# %%
print(x[-1])
# Out:
# arifa

# %%
print(x[0])
# Out:
# ['name', 34]

# %%
print(x[1])
# Out:
# sabitha

# %%
print(x[1:2])
# Out:
# ['sabitha']

# %%
print(x[0:2])
# Out:
# [['name', 34], 'sabitha']

# %%
print(x[:2])
# Out:
# [['name', 34], 'sabitha']

# %%
print(x[:])
# Out:
# [['name', 34], 'sabitha', 'misbna', 'arifa']

# %%
print(x[4:0])
# Out:
# []

# %%
print(x[0:])
# Out:
# [['name', 34], 'sabitha', 'misbna', 'arifa']

# %%
print(x[-1:3])
# Out:
# []

# %% [markdown]
# # **SLICING**

# %%
x=[['sabitha',30],'misna','arifa','fida']
print(x[0:3])
# Out:
# [['sabitha', 30], 'misna', 'arifa']

# %%
print(x[:3])
# Out:
# [['sabitha', 30], 'misna', 'arifa']

# %%
print(x[0:2])
# Out:
# [['sabitha', 30], 'misna']

# %%
print(x[:3])
# Out:
# [['sabitha', 30], 'misna', 'arifa']

# %%
print(x[:])
# Out:
# [['sabitha', 30], 'misna', 'arifa', 'fida']

# %%
print(x[1:])
# Out:
# ['misna', 'arifa', 'fida']

# %%
print(x[1:-1])
# Out:
# ['misna', 'arifa']

# %%
print(x[-3:-1])
# Out:
# ['misna', 'arifa']

# %%
print(x[1:3])
# Out:
# ['misna', 'arifa']

# %%
print(x[-3:0])
# Out:
# []
