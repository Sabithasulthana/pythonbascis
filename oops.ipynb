# %% [markdown]
# # **oops**

# %% [markdown]
# object  oriented programming is a programming paradigm that uses object and  classes in programming . it aims to to impliments real-word entities like inheritance,polymorphism, encapsulation. the main concepts of oops is to blind the data and function that work on that together as single unit so that no other part of the code can access this data.

# %% [markdown]
# **data**

# %% [markdown]
# python is muliparadigm language -procedural, fuctional,object oriented.

# %% [markdown]
# concept of loops

# %% [markdown]
# Abstraction

# %% [markdown]
# Polymorphism

# %% [markdown]
# Inheritance

# %% [markdown]
# **Class**

# %% [markdown]
# Class atribute

# %% [markdown]
# Class is a blue print or template

# %% [markdown]
# Blue print for objects

# %% [markdown]
# Function related to classes are methods

# %% [markdown]
# Defined usins "class'keywords

# %% [markdown]
# Class identifier follows class keywords

# %% [markdown]
# Conventionlly class identifier start with capilal character

# %% [markdown]
# Book as class name.

# %%
name= 'sabitha'
print(type(name))
name.upper()
# Out:
# <class 'str'>
# 'SABITHA'

# %% [markdown]
# **self**

# %% [markdown]
# self represents the instance of the class.By using the 'sel' we can access the atributes and methods of the class in python . self is parameter in function and user can use another parameter name in place of it. But it advisable to use self because it increases the readability of code.

# %%
class person:
  def read (self):
    print('person is reading')
  def walk(self):
    print('person is walking')
obj =person()
obj.read()
obj.walk()

obj1= person()
obj.walk()
# Out:
# person is reading
# person is walking
# person is walking

# %%
class person:
  def read(self):
    print('person is reading')
  def walk(self):
    print('person is walking')
obj1=person()

obj1.read()
obj1.walk()

obj4=person()
obj4.read()
# Out:
# person is reading
# person is walking
# person is reading

# %%
class House:
  def home(self, name,color,floor_material,roof_color):
    name= input('enter youer name')
    color= input('enter the color')
    floor_material=input('enter the floor_material')
    roof_color=input('enter the roof_color')

    self.name=name
    self.color=color
    self.floor_material=floor_material
    self.roof_color=roof_color

  def myhome(self):
   print('person name is %s color is %s, floor_material is %s roof_ color %s '%(self.name,self.color,self.floor_material,self.roof_color))
raju= House()
raju.home('sabitha','green','marble','blue')
raju.myhome()
# Out:
# enter youer namemisna
# enter the colorblue
# enter the floor_materialgranite
# enter the roof_colorred
# person name is misna color is blue, floor_material is granite roof_ color red

# %%
n= int(input('how many person details is you want to add:'))
for i in range(n):
  raju=House()
  raju.home('raju','white','marble','blue')
  raju.myhome()
# Out:
# how many person details is you want to add:2
# enter youer namesabitha
# enter the colorblue
# enter the floor_materialmarble
# enter the roof_colorarifa
# person name is sabitha color is blue, floor_material is marble roof_ color arifa
# enter youer namearifa
# enter the colorgreen
# enter the floor_materialgranite
# enter the roof_colorred
# person name is arifa color is green, floor_material is granite roof_ color red

# %% [markdown]
# **Inheritance**

# %% [markdown]
# **single** **inheritance**

# %% [markdown]
# single inheritance allow to derivate class into inherit properties of one part

# %%
class A:
  def printa(self,num):
    self.num=num
    print('inside class A')
class B(A):
  def printb(self):
    print('inside class B')
obj=B()
obj.printa('hello')
obj.printb()
# Out:
# inside class A
# inside class B

# %% [markdown]
# **multiple** **inheritance**:

# %% [markdown]
# if a class able to be created  from multiple base clases. this kind of inheritance is known as multiple inheritance.each of the arttributes that are present in the classes of the base has been passed on the classes that is derived from it.

# %%
class A:
  def printa(self):
    print('inside class A')
class B:
  def printb(self):
    print('inside class B')
class C(A,B):
  def printc(self):
    print('inside class C')
obj = C()
obj.printa()
obj.printb()
obj.printc()
# Out:
# inside class A
# inside class B
# inside class C

# %% [markdown]
# **Multi**  **Level** **Inheritance**

# %% [markdown]
# The features that are part of the original class as the class that is derived from it, are passed on to the new class. it is similar to a relationship involving grandparents and children.

# %%
class A:
  def printa(self):
    print('inside class A')
class B(A):
  def printb(self):
    print('inside class B')
class C(B):
  def printc(self):
    print('inside class C')
obj =C()
obj.printa()
obj.printb()
obj.printc()
# Out:
# inside class A
# inside class B
# inside class C

# %% [markdown]
# **Polymorphism**

# %% [markdown]
# The word means of polymorphism means having many forms.

# %% [markdown]
# polymorphism means same function name being uses for different types.

# %% [markdown]
# Two Types: OVERLODING ,OVERRIDING

# %% [markdown]
#  1) function over loding not support in python : class having more than one function with same name .

# %% [markdown]
# **OverLoding**

# %%
class new:
  def hello(self,s,b):
    self.s= s
    self.b=b
    print(self.s+self.b)
  def hello(self,a,b,c):
    self.a= a
    self.b= b
    self.c =c
    print(self.a+self.b+self.c)
obj1= new()
obj1. hello(4,5,67)
# Out:
# 76

# %%
class student:
  def sum(self,a,b):
     self.s= s
     self.b =b

  def sum(self, x=None,y=None,z=None):
      self.x =x
      self.y=y
      self.z=z


      s=0
      if x!=None and y!=None and z!=None:
        s=x+y+z
      elif x!=None and y!=None:
        s=x+y
      else:
        s=x
      return s
s1= student()
s1.sum(2,4)
# Out:
# 6

# %%
class point:
  def __init__(self, x,y):
    self.x=x
    self.y=y
  def __add__( self,other):
    x=self.x+ other.x
    y=self.y+ other.y
    return point(x,y)
p1 = point(5,7)
p2 = point(4,8)
print(p1+p2)

# %%
class point:
  def __int__(self,x,y):
    self.x=x
    self.y=y

  def __add__(self,other):
    x= self.x+other.x
    y=self.y+other.y
    return point(x,y)
  def _str_(self):
    return '({0},{1})'. format(self.x,self.y)

p1= point(5,7)
p2= point(4,8)
print(p1+p2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8c9f5d6f6c0a> in <cell line: 13>()
#      11     return '({0},{1})'. format(self.x,self.y)
#      12
# ---> 13 p1= point(5,7)
#      14 p2= point(4,8)
#      15 print(p1+p2)
#
# TypeError: point() takes no arguments
