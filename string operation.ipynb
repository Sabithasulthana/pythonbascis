# %% [markdown]
# # **STRING OPERATION**

# %%
x='hello how are you '
print(x.find('how'))
# Out:
# 6

# %%
print(x.find('how',1,9))
# Out:
# 6

# %%
print(x.find('how',1,8))
# Out:
# -1

# %%
x='hello how are you raju'
print(x)
# Out:
# hello how are you raju

# %%
y=x.rfind('raju',1,22)
print(y)
# Out:
# 18

# %%
z=x.split(' ')
print(z)
# Out:
# ['hello', 'how', 'are', 'you', 'raju']

# %% [markdown]
# **isalnum**

# %% [markdown]
# the isalnum method returns true if all the cheracters are the alphanumeric meaning alphaphet numbers (a-z)and numbers(0-9).space ,%,#,!,$, aer not valid

# %%
x= "company12"
y=x.isalnum()
print(y)
# Out:
# True

# %%
x="company 12"
y=x.isalnum()
print(y)
# Out:
# False

# %% [markdown]
# **stringjoin**

# %%
x=["hellow","how","are", "you","raju"]
y=' '.join(x)
print(y)
# Out:
# hellow how are you raju

# %%
z=['hello','world']
print(z)
s=' '.join(z)
print(s)
z=s.capitalize()
print(z)
# Out:
# ['hello', 'world']
# hello world
# Hello world

# %% [markdown]
# **upper**

# %%
w=s.upper()
print(w)
# Out:
# HELLO WORLD

# %% [markdown]
# **lower**

# %%
r=s.lower()
print(r)
# Out:
# hello world

# %% [markdown]
# **title**

# %%
t=s.title()
print(t)
# Out:
# Hello World
